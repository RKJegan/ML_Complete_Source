# %% [markdown]
# Data Types In Python

# %% [markdown]
# Numbers

# %%
1+1
# Out:
# 2

# %%
3-2
# Out:
# 1

# %%
4*5
# Out:
# 20

# %%
10/2
# Out:
# 5.0

# %%
10%2
# Out:
# 0

# %%
10 * 'a'
# Out:
# 'aaaaaaaaaa'

# %% [raw]
# Data Type Checking

# %%
type(1)
# Out:
# int

# %%
type('hello')
# Out:
# str

# %%
type("hello")
# Out:
# str

# %%
type(1.0)
# Out:
# float

# %%
print(type(True))
type(False)
# Out:
# <class 'bool'>
# bool

# %%
type(['1','2','3'])
# Out:
# list

# %% [markdown]
# String

# %%
"hello"
# Out:
# 'hello'

# %%
'Hello'
# Out:
# 'Hello'

# %%
type("jegan")
# Out:
# str

# %% [markdown]
# Variable Assignment

# %% [raw]
# var_name = value  #Syntax

# %%
a = 10
b = 20

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print((a*b)/(a+b))
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 6.666666666666667

# %% [markdown]
# Printing methods

# %%
a = 10
b = 25

# %%
print("first value is {} and second value is {}".format(a,b))
print("first value is {} and second value is {}".format(b,a))
# Out:
# first value is 10 and second value is 25
# first value is 25 and second value is 10

# %%
print("first value is {first} and second value is {second}".format(second = b,first = a))
# Out:
# first value is 10 and second value is 25
