# %% [markdown]
# BOOLEAN

# %%
bool()
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True),type(False)
# Out:
# (bool, bool)

# %%
st = "jegi1313"

# %%
print(st.isalnum())
print(st.isalpha())
print(st.isprintable())
print(st.rindex(st))
print(st.format())
print(st.isnumeric())
print(st.startswith('j'))
print(st.swapcase())
print(st.endswith('1'))
# Out:
# True
# False
# True
# 0
# jegi1313
# False
# True
# JEGI1313
# False

# %% [markdown]
# Boolean and Logical Operator

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %% [markdown]
# List

# %%
#Empty list
list1 = []
list2 = list()
type(list1),type(list2)
# Out:
# (list, list)

# %%
#list values by mannual
lst = ['1','2','abc','hig']
lst,len(lst)
# Out:
# (['1', '2', 'abc', 'hig'], 4)

# %%
#list values by append          -->adds value to last index and usefull for one value
lst.append('bis')

# %%
lst.append(['5','6'])

# %%
lst,len(lst)
# Out:
# (['1', '2', 'abc', 'hig', 'bis', 'bis', ['5', '6']], 7)

# %%
#Indexing in list
lst[2]             #--> list[index]
# Out:
# 'abc'

# %%
lst[:]           #-->list[start : end]
# Out:
# ['1', '2', 'abc', 'hig', 'bis', 'bis', ['5', '6']]

# %%
lst[2:]
# Out:
# ['abc', 'hig', 'bis', 'bis', ['5', '6']]

# %%
lst[:2]
# Out:
# ['1', '2']

# %%
#Insert in specific index 
lst.insert(2,'3')
lst
# Out:
# ['1', '2', '3', 'abc', 'hig', 'bis', 'bis', ['5', '6']]

# %%
# Extend Method            -->append multiple values by single use
l1 = ['1','2','3','4','5']
l1
# Out:
# ['1', '2', '3', '4', '5']

# %%
l1.extend(['6','7','8','9'])
l1
# Out:
# ['1', '2', '3', '4', '5', '6', '7', '8', '9']

# %% [raw]
# Operations in list

# %%
l2 = [1,2,3,4,5,6,7,8,9]

# %%
sum(l2)
# Out:
# 45

# %%
l2.pop()
# Out:
# 9

# %%
l2
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l2.pop(1)
l2
# Out:
# [1, 3, 4, 5, 6, 7, 8]

# %%
#Count
l3 = [1,1,1,3,2,4,5,6,8,4,3,4,3,3,2,3,4,5,4]

# %%
l3.count(3)    #--> return no. of occurance of value
# Out:
# 5

# %%
len(l3)      #--> total length
# Out:
# 19

# %%
l3.index(1)          #--> return index of first occurance of value
# Out:
# 0

# %%
l3.index(3)
# Out:
# 3

# %% [markdown]
# Sets

# %%
#Empty List

s = set()
type(s)
# Out:
# set

# %%
s1 = {1,2,3,4,5,6,3,2,1}     #--> duplicates are removed
s1,type(s1)
# Out:
# ({1, 2, 3, 4, 5, 6}, set)

# %% [markdown]
# SET In-Built Function

# %%
s1.add(7)
s1
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s2 = {1,2,3,4,5,5,4,7,7,8,6,5,9,9,2}
s2
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s2.difference(s1)
# Out:
# {8, 9}

# %%
s2.difference_update(s1)           #-->remove set element and update set which values are not in difference set
s2
# Out:
# {8, 9}

# %%
s3 = {1,2,3,4,5,6,7,8,9}
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
s3.intersection(s1)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %%
s3.intersection_update(s1)
s3
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# Dictionary

# %%
dic = {}
dic1 = dict()         #--> inbuilt dictionary function
type(dic),type(dic1)
# Out:
# (dict, dict)

# %%
#mannual way to create dictionary
d1 = {"c1":"BMW","c2":"Audi","c3":"Ferrari"}         #--> dictionary created with key
d1
# Out:
# {'c1': 'BMW', 'c2': 'Audi', 'c3': 'Ferrari'}

# %%
d1['c1']
# Out:
# 'BMW'

# %%
for i in d1:
    print(i)
# Out:
# c1
# c2
# c3

# %%
for i in d1.values():
    print(i)
# Out:
# BMW
# Audi
# Ferrari

# %%
for i in d1.items():
    print(i)
# Out:
# ('c1', 'BMW')
# ('c2', 'Audi')
# ('c3', 'Ferrari')

# %%
d1['c4'] = "McLearn"
d1
# Out:
# {'c1': 'BMW', 'c2': 'Audi', 'c3': 'Ferrari', 'c4': 'McLearn'}

# %%
d1['c4'] = "Volks Wagon"
d1
# Out:
# {'c1': 'BMW', 'c2': 'Audi', 'c3': 'Ferrari', 'c4': 'Volks Wagon'}

# %% [markdown]
# Neated Dictionary

# %%
M1 = {'BMW':'M2'}
M2 = {'BMW':'M2CS'}
M3 = {'BMW':'M3'}
ctype = {'c1':M1,'c2':M2,'c3':M3}
ctype,type(ctype)
# Out:
# ({'c1': {'BMW': 'M2'}, 'c2': {'BMW': 'M2CS'}, 'c3': {'BMW': 'M3'}}, dict)

# %%
ctype['c1']
# Out:
# {'BMW': 'M2'}

# %%
ctype['c3']
# Out:
# {'BMW': 'M3'}

# %%
print(ctype['c3']['BMW'])
# Out:
# M3

# %% [markdown]
# Tuples

# %%
# Tuple Creation
t1 = tuple()
type(t1)
# Out:
# tuple

# %%
t1 = (1,2,'a','b')
t1
# Out:
# (1, 2, 'a', 'b')

# %%
# inbuilt function

t1 = (1,1,2,1,3,4,5,4,3,5,'a','a','b')
t1
# Out:
# (1, 1, 2, 1, 3, 4, 5, 4, 3, 5, 'a', 'a', 'b')

# %%
t1.count(1)
# Out:
# 3

# %%
t1.count('a')
# Out:
# 2

# %%
t1.index(3)
# Out:
# 4

# %%
t1.index('a')
# Out:
# 10
